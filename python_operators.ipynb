# %% [markdown]
# # Python Operators Practice Notebook
#
# Each question is followed by its solution in the next code cell.
# Difficulty level: Easy to Medium.

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Q1. Add two numbers a = 10 and b = 5.

# %%
# write your answer here
sum_result = 10 + 5
print(sum_result)
# Out:
# 15

# %% [markdown]
# Q2. Find the remainder when 17 is divided by 4.

# %%
# write your answer here
remainder = 17 % 4
print(remainder)
# Out:
# 1

# %% [markdown]
# Q3. Calculate 3 raised to the power 4.

# %%
# write your answer here
power_result = 3 ** 4
print(power_result)
# Out:
# 81

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# Q4. Assign 10 to x and add 5 to it using assignment operator.

# %%
# write your answer here
x = 10
x += 5
print(x)
# Out:
# 15

# %% [markdown]
# Q5. Assign 20 to y and multiply it by 2 using assignment operator.

# %%
# write your answer here
y = 20
y *= 2
print(y)
# Out:
# 40

# %% [markdown]
# Q6. Assign 15 to z and subtract 7 using assignment operator.

# %%
# write your answer here
z = 15
z -= 7
print(z)
# Out:
# 8

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Q7. Check if 10 is greater than 5.

# %%
# write your answer here
num = 10
if num > 5:
    print("10 is greater than 5")
else:
    print("10 is not greater than 5")
# Out:
# 10 is greater than 5

# %% [markdown]
# Q8. Check if 7 is equal to 9.

# %%
# write your answer here
num1 = 7
num2 = 9
if num1 == num2:
    print("7 is equal to 9")

# %% [markdown]
# Q9. Check if 8 is not equal to 3.

# %%
# write your answer here
num = 8
if num != 3:
    print("8 is not equal to 3")
else:
    print("8 is equal to 3")
# Out:
# 8 is not equal to 3

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# Q10. Check if 5 > 2 and 10 > 3.

# %%
# write your answer here
if 5 > 2 and 10 > 3:
    print("5 is greater than 2 and 10 is greater than 3")
# Out:
# 5 is greater than 2 and 10 is greater than 3

# %% [markdown]
# Q11. Check if 5 > 10 or 3 < 7.

# %%
# write your answer here
if(5 > 10 or 3 < 7):
    print("At least one condition is true")
else:
    print("Both conditions are false")
# Out:
# At least one condition is true

# %% [markdown]
# Q12. Use not operator on condition 10 > 5.

# %%
# write your answer here
not (10 > 5)
# Out:
# False

# %% [markdown]
# ## Identity Operators

# %% [markdown]
# Q16. Check if a and b refer to the same object.
# Let a = 10, b = 10.

# %%
# write your answer here
a,b = map(float, input("Enter the value of two numbers: ").split())
if(a == b):
  print("a and b refer to the same object")
else:
  print("a and b do not refer to the same object")
# Out:
# a and b do not refer to the same object

# %% [markdown]
# Q18. Compare identity of two variables c and d where c = d = 5.

# %%
# write your answer here
c = 5
d = 5
if(c == d):
  print("c and d refer to the same object")
else:
  print("c and d do not refer to the same object")
# Out:
# c and d refer to the same object

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# Q19. Check if 3 is present in the list [1,2,3,4].

# %%
# write your answer here
list = [1,2,3,4]
if 3 in list:
  print("3 is present in the list")
else:
  print("3 is not present in the list")
# Out:
# 3 is present in the list

# %% [markdown]
# Q20. Check if 'a' is not present in the string 'python'.

# %%
# write your answer here
string = 'python'
if 'a' not in string:
  print("'a' is not present in the string")
else:
  print("'a' is present in the string")
# Out:
# 'a' is not present in the string

# %% [markdown]
# Q21. Check if 10 is in the tuple (5, 10, 15).

# %%
# write your answer here
tuple = (5, 10, 15)
if 10 in tuple:
  print("10 is in the tuple")
else:
  print("10 is not in the tuple")
# Out:
# 10 is in the tuple
