# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
tup = (25,65,98,33,45)
print(tup,end="\n")
for x in tup:
    print(x, end = " ")
# Out:
# (25, 65, 98, 33, 45)
# 25 65 98 33 45

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
tup1 = (12,"Sandy",True,88.88)
for x in tup1:
    print(x,end=" ")
# Out:
# 12 Sandy True 88.88

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
names = ("Sandy","aditi","Pawan","Aakash")
print("The length of names is: ",len(names))
# Out:
# The length of names is:  4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
names = ("Sandy","aditi","Pawan","Aakash")
print(names[-1])
# Out:
# Aakash

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
names = ("Sandy","aditi","Pawan","Aakash")
element = input("Enter the element to find: ")
if x in names:
    print("Element present")
else:
    print("ELment not present")
# Out:
# Element present

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
tuple1 = (56,88,"sandy","Shivansh")
list1 = [tuple1]

print(list1)
print(type(list1))
# Out:
# [(56, 88, 'sandy', 'Shivansh')]
# <class 'list'>

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
list2 = ["rahul","badal",58,65.1]
tup2 = (list2,)
print(type(tup2))
print(tup2)
# Out:
# <class 'tuple'>
# (['rahul', 'badal', 58, 65.1],)

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here
tup = (1,1,255,45,36,78,78,45,255,36,45,1,36)
s = []
for x in tup:
    if x not in s:
        print("The count of",x, "is:", tup.count(x),end ="\n")
        s.append(x)
# Out:
# The count of 1 is: 3
# The count of 255 is: 2
# The count of 45 is: 3
# The count of 36 is: 3
# The count of 78 is: 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
tup9 = (89,78,56,32,45)
print(tup9.index(89))
# Out:
# 0

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
tup0 = (45,89,63,45)
tup[8]="Sandy"

#It is giving error that tuple object does not support item assignment so it means tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # write your answer here
#       2 tup0 = (45,89,63,45)
# ----> 3 tup[8]="Sandy"
#
# TypeError: 'tuple' object does not support item assignment
